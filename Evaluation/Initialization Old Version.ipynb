# %%
import xlrd
import pandas as pd
import pickle
video_data = pd.read_csv('MSR Video Description Corpus.csv')

# %%
video_data = video_data[video_data['Language'] == 'English']

videoID_lists = list(video_data['VideoID'])
videoID_start_lists = list(video_data['Start'])
videoID_end_lists = list(video_data['End'])
video_descriptions_lists = list(video_data['Description'])

videoID_with_Frames = []
for idx, item in enumerate(videoID_lists):
    temp = videoID_lists[idx] + '_' + str(int(videoID_start_lists[idx])) + '_' + str(int(videoID_end_lists[idx]))
    #temp = videoID_lists[idx]
    videoID_with_Frames.append(temp)

# videoID map
videoID_shrinked = list(set(videoID_with_Frames))

map_videoID = {}
for idx, item in enumerate(videoID_shrinked):
    map_videoID[idx] = item

# %%
def is_ascii(s):
    return all(ord(c) < 128 for c in s)

# %%
json_fd = open('reference.json', 'w')
json_fd.write('{"info": {"description": "ground truth", "version": "1.0", "year": 2019, "date_created": "2019-03-17"}, "images": [')


tmp_idx = 1
for key in map_videoID:
    if tmp_idx != len(map_videoID):
        json_fd.write('{"license": 1, "file_name": "' + str(map_videoID[key]) + '", "id": ' + str(key) + '}, ')
    if tmp_idx == len(map_videoID):
        json_fd.write('{"license": 1, "file_name": "' + str(map_videoID[key]) + '", "id": ' + str(key) + '}], ')
    tmp_idx += 1

json_fd.write('"licenses": [{"url": "http://creativecommons.org/licenses/by-nc-sa/2.0/", "id": 1, "name": "Attribution-NonCommercial-ShareAlike License"}], ')
json_fd.write('"type": "captions", "annotations": [')

id_count = 0
for count, key in enumerate(map_videoID):
    video_frame = map_videoID[key]
    indices = [i for i, x in enumerate(videoID_with_Frames) if x == video_frame]
    if count != len(map_videoID)-1:
        for idx in indices:
            if type(video_descriptions_lists[idx]) == type(1.0):
                continue
        
            if '\\' in video_descriptions_lists[idx]:
                print (video_descriptions_lists[idx])
                continue

            if '"' in video_descriptions_lists[idx]:
                print (video_descriptions_lists[int(idx)])
                continue
        
            if "\n" in video_descriptions_lists[idx]:
                print (video_descriptions_lists[int(idx)])
                continue

            if is_ascii(video_descriptions_lists[idx]):
                json_fd.write('{"image_id": ' + str(key) + ', "id": ' + str(id_count) + ', "caption": "' + str(video_descriptions_lists[idx]) + '"}, ')
                id_count = id_count + 1

    if count == len(map_videoID)-1:
        for ii, idx in enumerate(indices):
            if type(video_descriptions_lists[idx]) == type(1.0):
                continue
        
            if '\\' in video_descriptions_lists[idx]:
                print (video_descriptions_lists[idx])
                continue
        
            if '"' in video_descriptions_lists[idx]:
                print (video_descriptions_lists[int(idx)])
                continue
        
            if "\n" in video_descriptions_lists[idx]:
                print (video_descriptions_lists[int(idx)])
                continue
            
            if ii != len(indices)-1:
                json_fd.write('{"image_id": ' + str(key) + ', "id": ' + str(id_count) + ', "caption": "' + str(video_descriptions_lists[idx]) + '"}, ')
                id_count = id_count + 1
            if ii == len(indices)-1:
                json_fd.write('{"image_id": ' + str(key) + ', "id": ' + str(id_count) + ', "caption": "' + str(video_descriptions_lists[idx]) + '"}]}')

json_fd.close()
# Out:
# A little boy standing alone in front of a goal post ecstatically screams, “Yes!"
# Two men"s are talking to pizza boy
# A man clean another man"s shirt
# Bob Marley playing and singing the song, "Stir it up"
# The person"s are making music
# A man takes off sunglasses from his face and says," I beg to differ."
# A big cat fought with a smll black cat.
# Tat big cat is drinking its food.
# It also dashes the little child.
# Somebody helping it for iching its body.
# Small black cat act as dead one.
# The cat jumps higher.
# Two cats are disturbing a person.
# One cat fell into a box.
# A cat gets scarred.
# A cat forced down a child  in ground.
# A cat disturbes the fishes and fish tank settings.
# A dog and a cat fights each other.
# A bear scarred of a cat.
# A rat rotates a cat.
# A cat rotates a bed.
# On friday work,penguins enjoys with its family and swims in water.
# On monday work,a single polar  fell in ice.
# a dog was skateboarding.Eventhough a drum falls,its getting skate board safely and again doing  excellent skateboarding in a road near beach.
# Many people"s are traveling in the boat
# A boy made a skull "talk" by moving the mouth with his hands.
# A man is showing demo for "ashtanga yoga".
# a nife on the cutting
#
#
#
#
#
#
#
# cutting on the nife
# this is
# Lazy Man's Pork Chops
# Football players learning the four "R's".
# A woman is "dancing" while sitting on some steps, then hits her elbow.
# A man takes an "EZ Cracker" out of its box.
# It's a boxing scene from the film "Rocky 1"
# A chef is preparing Japanese food "Chimichuuri sause"
# A man is slicing some Potato’s.
#
#
# .
# the kids are cute..but the guy﻿ talking toomuch.
# and three kids bath for tube.
# An episode of "I Love Lucy" where Desi lights Lucy a cigarette.
# A scene from fro a movie named 'Pallavi and Anupallavi"
# A lady is washing  a piece of
# meat.
# good song nice to heare good hard﻿ work.
#
# thanks for uploading this song Mr.RajiCreativeWorks
# A person"s wife in the hospital
# trailer of movie"legend of zelda"
# TRAILER FOR FILM "lEGEND OF ZELDA"
# The lovers dancing with love song
# The Girl sings the song and boy give music to it
# Some people were hanging at Herrick company on July 13 and 14,2009.
# The connectors are Dan and Keith.
# "Frankenstein" is carrying a man over his shoulder.
# The bar scene from the Eddie Murphy movie "Coming to America".
# Music video starring "Surfer Blood" doing Swim.
# A baby makes "happy" and "mad" faces.
# Two women"s are fighting to gather
# "Oh! I cant be wet", says monkey.
# Somebody typing on "Dell" keyboard
# A woman is passing balls to another woman who is practicing
# hitting a volley ball.
# Robert Rodriquez doing a demonstration of how to make Sin City
# breakfast tacos.
# Someone is scanning through computer files and labels a folder "LOL".
# someone is doing horse rig\ding ina stadium
# A Actor"s are acting in the film
# MASTODON - "Seabeast"
# Lionel Richie is dancing in a video and ends up "dancing on the ceiling."
# the girl is showing
# 10 Minute Jump Rope Cardio Workout
# From what I can see, this man is the product of Peter Jackson, Hurley from Lost, and Hagrid having a baby. Then God﻿ went "Holy Hell! Three men making a baby?! This one's special!" So he blessed him with the best damn guitar skills ever seen on Earth.
# Many people"s are dancing in the disco
# "I will separate the onion into neutrons and protons in seconds."
# Two girls are dancing to "Soldier Boy."
# A woman is slicing the Prawns.
#
# A short clip aboout Japanese Boxed Lunch "Bento".
# Adam Voges on "that catch" KFC Twenty20 vs New Zeland.
# A
# n
# Woman i
# s
#
# An Woman is slicing a tomatoe
# A man makes a rude gesture to his opponent that implies "fuck you".
# Two girls each eating a hamburger in the kitchen, standing next to a boy exclaim," Hmm, delicious".
# A dear steel a man"s wife
# Guitar played by a professional in "Take me home"
# many man"S are on the ride with horse
# This is a deleted scene from the Hollywood movie " Gladiator".
# A woman is creating a bubble with the product, "Bubble Thing".
# This is the funniest science fiction apocalyptic movie that I have seen yet! I give it two thumbs up! the Chicken littles of the world will be so frightend by it﻿ and keep shouting "THE SKY IS FALLING!" while running in circles.
# Man"s is swimming in the water
# A fog monster occur"s
# Routine workout by prisoners in movie " Mean Machine "
# Many person"s are doing the exercise
# A man is standing outdoors on the edge of a parking lot speaking into a microphone while a red banner is displayed across his chest reading "Manchester Fox Ct Morning News"
# A chef is cutting onions for
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A chef is cutting onions for Chinese cooking.
# This cute little girl is dancing to "The Itsy-Bitsy Spider" and cleaning up her toys.
# The Tamil actors are singing song "Vennilave"
# are you asking about the tune﻿ that starts? that would be "collumbus" sang by ar rahman from da film jeans
# A movie clip about the movie "Damaged Goods" a teen-age sex story.
# In this show of "Cooking with Jack" episode 32nd being "Pizza Wars" held at the cortina's Italian market & pizzeria the California dough was judged better than the Newyork dough.
# Pawan kalyan breaking the pot"s
# A man is slicing a peeled onion into four uniform slices of about 1/2" thickness each.
# A person making Hungarian Crepes" with Peter Vamos
# how to make hungarian crepes"with peter vamos
# A man is beating push up"S by one hand
# A female is reading a magazine, entitled "Bohemian".
# Zebra"s having they food
# A man is drawing Lucy from "The Peanut" comic strip.
# A dog appears to be saying "I want my mama."
# A dog barking "I want my mama".
# A woman drives "The Arnold" down the street in a convertible.
# It is a scene from the Hollywood movie "Commondo"
# Two boy"s are making music
# Drinya is cute - but we﻿ miss Sonya! Please, more vids!
#
# thx:-)Im sure Drinya moves more than Sonya﻿ because hes younger and more agile?
# A man brings his face really close and says," My name is Mud".
# Many person"s are fighting
# The actual title of this film is "SHAOLIN AND WU-TANG". 'Shaolin VS Wu-Tang' is﻿ the original Chinese title for Chang Cheh's 'Two Champions Of Shaolin', starring the cast of 5 Venoms
# A man is playing a piano composition from " The Betrayal"
# Many person"s is watching the air show
# This is not an "Almiqui" from cuba (Solenodon cubanus), this is an endemic animal from dominican republic called Solenodon paradoxus. their population is very low thanks to dogs, wild cats, the african mangoose (Herpestes auropunctatus), and of﻿ course the humans who used to hunt them for food.
# The player"s is putting the ball into the basket
# creo que podria ser la mascota del﻿ niño mas tonto del mundo
#
# PD:﻿ jajaja
# RC Adventure of a small plane looks beautiful!
# It sparks like an airforce force!
# A text overlay that says "Inspired presents" is shown.
# A lady is preparing "Beef Brocolli".
# A pug is moving around in a way that resembles the "Moonwalk" dance.
# A person is caring small animals on her ham\nds

# %%
import os
f = open("S2VT_results.txt")
vids = []
ress = []
for x in f:
  if x.find("/content/") != -1:
    arr = x.split('/')
    stri = arr[len(arr) - 1]
    res = stri[:len(stri) - 5]
#     print("before : {} after {}".format(stri, res))
    vids.append(res)
  elif x != '\n' :
    ress.append(x.rstrip('\n'))

map_videoID_reverse = {}
for key in map_videoID:
    val = map_videoID[key]
#     print(val)
    map_videoID_reverse[val] = key
    
json_fd = open('generation.json', 'w')
json_fd.write('[')
#print(vids[7])
for i in range(len(vids)):
#     print(vids[i])
#     print(ress[i])
    if i != len(vids)-1:
        json_fd.write('{"image_id": ' + str(map_videoID_reverse[vids[i]]) + ', "caption": "' + ress[i] + '"}, ')
    if i == len(vids)-1:
        json_fd.write('{"image_id": ' + str(map_videoID_reverse[vids[i]]) + ', "caption": "' + ress[i] + '"}]')

json_fd.close()
